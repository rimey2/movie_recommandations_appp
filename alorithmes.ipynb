# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MultiLabelBinarizer
import streamlit as st

# %%
df = pd.read_csv('movies.csv')
df
# Out:
#                                                   title  movieId  \
# 0                                    Lion of the Desert     5196
# 1                                              Commando   153496
# 2                                              Commando     6664
# 3                                              Commando   189687
# 4                                     The Thin Red Line   166237
# ...                                                 ...      ...
# 4612                                    Mars Needs Moms    85261
# 4613                                             Robots    32031
# 4614  Aqua Teen Hunger Force Colon Movie Film for Th...    52462
# 4615                                          Enchanted    56152
# 4616                                             Rubber    81132
#
#         director_name   actor_2_name  \
# 0     Moustapha Akkad    Rod Steiger
# 1      Mark L. Lester   Vernon Wells
# 2      Mark L. Lester   Vernon Wells
# 3      Mark L. Lester   Vernon Wells
# 4     Terrence Malick   Miranda Otto
# ...               ...            ...
# 4612      Simon Wells     Dan Fogler
# 4613      Chris Wedge     Drew Carey
# 4614   Matt Maiellaro   Fred Armisen
# 4615       Kevin Lima     Teala Dunn
# 4616  Quentin Dupieux  Jack Plotnick
#
#                                                 genres       actor_1_name  \
# 0                          Biography|Drama|History|War        Oliver Reed
# 1                            Action|Adventure|Thriller          Bill Duke
# 2                            Action|Adventure|Thriller          Bill Duke
# 3                            Action|Adventure|Thriller          Bill Duke
# 4                                            Drama|War         Nick Stahl
# ...                                                ...                ...
# 4612   Action|Adventure|Animation|Comedy|Family|Sci-Fi  Elisabeth Harnois
# 4613          Adventure|Animation|Comedy|Family|Sci-Fi      Jim Broadbent
# 4614  Action|Adventure|Animation|Comedy|Fantasy|Sci-Fi           Tina Fey
# 4615   Animation|Comedy|Family|Fantasy|Musical|Romance       Jeff Bennett
# 4616                             Comedy|Fantasy|Horror         Haley Ramm
#
#                                             movie_title        actor_3_name  \
# 0                                   Lion of the Desert         John Gielgud
# 1                                             Commando       Rae Dawn Chong
# 2                                             Commando       Rae Dawn Chong
# 3                                             Commando       Rae Dawn Chong
# 4                                    The Thin Red Line           Dash Mihok
# ...                                                 ...                 ...
# 4612                                   Mars Needs Moms    Tom Everett Scott
# 4613                                            Robots          Paula Abdul
# 4614  Aqua Teen Hunger Force Colon Movie Film for Th...        Chris Kattan
# 4615                                         Enchanted      Fred Tatasciore
# 4616                                            Rubber   Cecelia Antoinette
#
#                                           plot_keywords  \
# 0                   arab|general|libya|muslim|mussolini
# 1     body count|dictator|jumping from an airplane|k...
# 2     body count|dictator|jumping from an airplane|k...
# 3     body count|dictator|jumping from an airplane|k...
# 4     battle|hill|jungle|multiple perspectives|tropi...
# ...                                                 ...
# 4612                    boy|martian|rescue|robot|sexism
# 4613  actor voicing multiple characters|box office h...
# 4614  based on cult tv series|critically acclaimed|e...
# 4615             fairy tale|lawyer|love|new york|prince
# 4616                    desert|dump|show|spectator|tire
#
#                                         movie_imdb_link
# 0     http://www.imdb.com/title/tt0081059/?ref_=fn_t...
# 1     http://www.imdb.com/title/tt0088944/?ref_=fn_t...
# 2     http://www.imdb.com/title/tt0088944/?ref_=fn_t...
# 3     http://www.imdb.com/title/tt0088944/?ref_=fn_t...
# 4     http://www.imdb.com/title/tt0120863/?ref_=fn_t...
# ...                                                 ...
# 4612  http://www.imdb.com/title/tt1305591/?ref_=fn_t...
# 4613  http://www.imdb.com/title/tt0358082/?ref_=fn_t...
# 4614  http://www.imdb.com/title/tt0455326/?ref_=fn_t...
# 4615  http://www.imdb.com/title/tt0461770/?ref_=fn_t...
# 4616  http://www.imdb.com/title/tt1612774/?ref_=fn_t...
#
# [4617 rows x 10 columns]

# %%
df=pd.read_csv("ratings.csv")
df
# Out:
#           userId  movieId  rating   timestamp
# 0          18560      516     5.0  1145303288
# 1         122553      261     5.0   839352591
# 2         154994      266     5.0   941588514
# 3         135201     3594     5.0  1012191276
# 4         116535     1291     5.0  1359679804
# ...          ...      ...     ...         ...
# 13009875  136211     1196     3.5  1376254388
# 13009876   10570   112556     3.5  1494152642
# 13009877  115716     2990     3.5  1056487869
# 13009878  121473     3246     3.5  1497227343
# 13009879  155263     8368     3.5  1455466330
#
# [13009880 rows x 4 columns]

# %%
## TRAINEMENT NETTOYAGE ET PROCESSING DES DONNEES

# %%
##  Chargement et preprocessing des données

# %%
def traitement():
    ratings_df = pd.read_csv('ratings.csv')
    movies_df = pd.read_csv('movies.csv')
       
    movies_df = movies_df.drop_duplicates(subset='movie_title', keep='first')
    movies_df['genres'] = movies_df['genres'].str.split('|')
    
    mlb = MultiLabelBinarizer()
    genres_encoded = pd.DataFrame(mlb.fit_transform(movies_df['genres']),
                                columns=mlb.classes_,
                                index=movies_df.index)
    
    ## on doit fusionner des caractéristiques dans un DataFrame

    features = pd.concat([
        genres_encoded,
        pd.get_dummies(movies_df['director_name']),
        pd.get_dummies(movies_df['actor_1_name']),
        pd.get_dummies(movies_df['actor_2_name']),
        pd.get_dummies(movies_df['actor_3_name'])
    ], axis=1)
    
    return ratings_df, movies_df, features

# %%
#### RECOMMANDATIONS COLLABORATIVES

# %%
def recos_collaboratives(movie_title, movies_df, ratings_df, n_recommandations=5):
    
    movie_id = movies_df[movies_df['movie_title'] == movie_title]['movieId'].iloc[0]
    
    # Création de la  matrice utilisateur-film
    ratings_matrix = pd.pivot_table(ratings_df, values='rating', 
                                  index='userId', columns='movieId', fill_value=0)
    
    # Calculer la similarité entre les films
    movie_similarity = cosine_similarity(ratings_matrix.T)
    movie_similarity_df = pd.DataFrame(movie_similarity, 
                                     index=ratings_matrix.columns,
                                     columns=ratings_matrix.columns)
    
    # Obtenir les films similaires
    similar_scores = movie_similarity_df[movie_id].sort_values(ascending=False)
    similar_movies = similar_scores.index[1:n_recommandations+1].tolist()
    
    recommandations = movies_df[movies_df['movieId'].isin(similar_movies)][['movie_title', 'genres']]
    return recommandations

# %%
## RECOMMANDATIONS SUR LE CONTENU

# %%
def recos_contenus(movie_title, movies_df, content_features, n_recommandations=5):
    
    # Trouver l'index du film sélectionné
    movie_idx = movies_df[movies_df['movie_title'] == movie_title].index[0]
    
    # Calculer la similarité basée sur le contenu
    similarity = cosine_similarity(content_features)
    similar_scores = pd.Series(similarity[movie_idx], index=movies_df.index)
    
    # Obtenir les films similaires
    similar_movie_indices = similar_scores.sort_values(ascending=False)[1:n_recommandations+1].index
    recommandations = movies_df.iloc[similar_movie_indices][['movie_title', 'genres']]
    return recommandations
